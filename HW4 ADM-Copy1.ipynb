# %% [markdown]
# # 1. Processing JSON file and creation of a graph G

# %% [markdown]
# Parsing for the json files

# %%
import json
import networkx as nx
import itertools
from datetime import datetime
import matplotlib.pyplot as plt

# %%
data = json.load(open('/Users/liviodonnini/Desktop/adm_hw4/reduced_dblp.json'))
#print(data)

# %% [markdown]
# Define a dictionary to easily find the author ID for a given author name in input:

# %%
nameID = {}
for i in range (len(data)):
    for j in range(len(data[i]['authors'])):
        key = data[i]['authors'][j]['author']
        nameID[key] = data[i]['authors'][j]['author_id']

# %%
nameID['aris anagnostopoulos']
# Out:
# 256176

# %% [markdown]
# Define a dictionary containing all the publications for a given author:

# %%
authorsDict = {} # For each author: authors_id & id_publication_int that they enjoyed
                 # the keys are the authors' ID's
'''
# If we need a dict of only author_id and author
for i in range(len(data)):
    for a in data[i]['authors']:
        for j in range(len(data[i]['authors'])):
            key = data[i]['authors'][j]['author_id']
            authorsDict[key] = data[i]['authors'][j]['author']
'''

# key: author id, value = list(publication1,pub2,...)
for i in range(len(data)):
    for author in data[i]['authors']: 
        for j in range(len(data[i]['authors'])):
            key = data[i]['authors'][j]['author_id'] # the key is the ID for every author
            if key in authorsDict.keys(): 
                if data[i]['id_publication_int'] not in authorsDict[key]:
                    authorsDict[key].append(data[i]['id_publication_int'])
            else:
                authorsDict[key] = [data[i]['id_publication_int']]
authorsDict
# Out:
# {255206: [161535],
#  255207: [161535],
#  16585: [161535],
#  255208: [161535],
#  255280: [161584],
#  255281: [161584],
#  3326: [161584],
#  20405: [161623, 638442],
#  20407: [161623, 638442],
#  255339: [161641],
#  205380: [161641],
#  115228: [161641],
#  210891: [161677],
#  255394: [161677],
#  255395: [161677],
#  255405: [161687, 870141],
#  9308: [161687, 383148, 383188],
#  175195: [161687],
#  17178: [161687],
#  176994: [161717],
#  73799: [161717],
#  24151: [161717, 733292],
#  255487: [161751],
#  255488: [161751],
#  3476: [161751],
#  255489: [161751],
#  166813: [161756],
#  13781: [161756],
#  9741: [161777],
#  8757: [161777],
#  255537: [161790],
#  21462: [161790, 254014],
#  255578: [161821],
#  113776: [161888],
#  255247: [161888],
#  82068: [161888],
#  255673: [161888],
#  255688: [161896, 427806, 733432],
#  255689: [161896],
#  255690: [161896],
#  255691: [161896],
#  113346: [161920],
#  15924: [161971, 254043, 426495, 639405],
#  255814: [162007],
#  200773: [162007],
#  93126: [162021, 730272, 731280],
#  23845: [162021],
#  208589: [162021],
#  127810: [162086],
#  255902: [162086, 162674, 868651],
#  255926: [162116, 732891],
#  9503: [162116, 731280],
#  9505: [162116, 730342],
#  9068: [162135],
#  9046: [162135],
#  9069: [162135],
#  9070: [162135],
#  255950: [162140],
#  255996: [162188, 732068],
#  20199: [162188],
#  124828: [162227],
#  239007: [162227],
#  189237: [162227],
#  255823: [162232],
#  256123: [162307, 383301],
#  256124: [162307, 162460],
#  8985: [162309, 639653, 658590, 730877],
#  8987: [162309, 427067],
#  8988: [162309,
#   175585,
#   342453,
#   382686,
#   383858,
#   638481,
#   639113,
#   639653,
#   659863,
#   868121,
#   869208,
#   869713,
#   869855],
#  19285: [162311, 382979, 427879, 639152, 639294],
#  19460: [162311],
#  8612: [162311, 639152, 871198],
#  255494: [162328],
#  256146: [162332],
#  256147: [162332],
#  9771: [162332],
#  256148: [162332],
#  20336: [162342, 253807, 253871, 638940],
#  256176: [162358,
#   175568,
#   254068,
#   254234,
#   342298,
#   354200,
#   382418,
#   425337,
#   427289,
#   486893,
#   494767,
#   544318,
#   638333,
#   658645,
#   731279,
#   866799,
#   869138,
#   954951,
#   979491],
#  256177: [162358],
#  255328: [162358, 638644, 639405],
#  256188: [162367],
#  256159: [162404],
#  256133: [162404],
#  256264: [162448],
#  256265: [162448],
#  256276: [162460],
#  25696: [162498],
#  255805: [162498],
#  72882: [162499],
#  72883: [162499],
#  71582: [162499],
#  71969: [162499],
#  9772: [162537],
#  114626: [162537],
#  114625: [162537],
#  114483: [162546, 731257, 732029],
#  202882: [162546],
#  256135: [162546, 638428, 658023],
#  252278: [162589],
#  83637: [162622],
#  83639: [162622],
#  255300: [162632, 732891],
#  21056: [162632],
#  70758: [162632],
#  256482: [162661, 253699, 253723, 253803, 254168, 870107],
#  256500: [162674],
#  20392: [162686, 425244, 425764, 426399, 427503, 659765],
#  8857: [162686],
#  256366: [162730],
#  255759: [162753],
#  255760: [162753],
#  8874: [162753],
#  19794: [162753, 342253],
#  9451: [162795],
#  8350: [162795],
#  8352: [162795, 731065],
#  151570: [162806],
#  43462: [162806],
#  9388: [162806],
#  1632: [175151],
#  217858: [175151],
#  271609: [175151],
#  17344: [175151],
#  16239: [175151],
#  271610: [175151],
#  8819: [175152],
#  271611: [175152],
#  16249: [175152],
#  19355: [175152],
#  16145: [175152, 175452, 175649, 176000],
#  18433: [175152],
#  223848: [175152],
#  271612: [175152],
#  175489: [175152],
#  271613: [175152],
#  17368: [175152],
#  271614: [175152],
#  17611: [175152, 176093, 638639],
#  16521: [175152],
#  168357: [175152, 176001],
#  271615: [175152],
#  271616: [175152],
#  17509: [175153],
#  17973: [175153],
#  17974: [175153, 175372, 487521],
#  16665: [175153, 869907],
#  16837: [175153, 253842, 254150, 658064, 870739],
#  16867: [175159, 176454, 870177],
#  271623: [175159],
#  17824: [175159, 658101, 732493],
#  15938: [175159,
#   382996,
#   383083,
#   383756,
#   383768,
#   426936,
#   638985,
#   639376,
#   640028,
#   658101,
#   868114,
#   870205],
#  271632: [175172],
#  271633: [175172],
#  16483: [175172, 175485, 175648, 175758],
#  17423: [175175],
#  15815: [175175, 175179, 175608, 176613, 868056],
#  17426: [175175, 176083],
#  16053: [175175, 175608, 639416],
#  15816: [175175, 176613, 868056],
#  16309: [175178],
#  15983: [175178, 382561, 639860],
#  15982: [175178, 175532, 382561, 639860, 639962, 868111, 870177],
#  17853: [175179],
#  16752: [175179, 868056],
#  17184: [175179, 487521, 494782, 544710, 733551],
#  17829: [175191, 658268],
#  15850: [175191, 175779, 176454, 383533, 869010],
#  16486: [175191, 175779],
#  18268: [175191],
#  271670: [175204],
#  17466: [175204, 175296],
#  271671: [175204],
#  272243: [175766],
#  218972: [175766],
#  218970: [175766],
#  217845: [175766, 354236],
#  18427: [175771],
#  17372: [175771, 176077],
#  272247: [175771],
#  16842: [175771, 176229],
#  272253: [175776],
#  272254: [175776],
#  18208: [175776],
#  272255: [175776],
#  17244: [175776],
#  272256: [175776],
#  16487: [175779],
#  15839: [175779, 176706, 383255],
#  15841: [175779, 176706],
#  16049: [175791, 639826],
#  16045: [175791, 427122, 639826],
#  16050: [175791, 639826],
#  18826: [175791],
#  260828: [175799],
#  16798: [175799],
#  272302: [175817],
#  272303: [175817],
#  97887: [175817],
#  18167: [175817],
#  272224: [175818],
#  17011: [175818],
#  16301: [175818, 176088, 342792, 639051, 659695],
#  16330: [175818],
#  17326: [175822],
#  271895: [175825],
#  272127: [175825],
#  17604: [175825],
#  113958: [175825, 176178],
#  16356: [175825],
#  272316: [175825],
#  272317: [175825],
#  272318: [175825],
#  32665: [175842],
#  272352: [175842],
#  17097: [175842, 382397, 869622],
#  272367: [175852],
#  128303: [175854],
#  272368: [175854],
#  272396: [175881],
#  7927: [175881, 176519],
#  272399: [175885],
#  272400: [175885],
#  272401: [175885],
#  87752: [175885],
#  158398: [175885],
#  272402: [175885],
#  15975: [175885],
#  272403: [175885],
#  16277: [175926],
#  272162: [175926],
#  272440: [175926],
#  48526: [175926, 175949],
#  255725: [175936],
#  272445: [175936],
#  17443: [175936],
#  15948: [175936],
#  19369: [175938],
#  16782: [175938],
#  223877: [175949],
#  16338: [175949],
#  16553: [175954],
#  16554: [175954, 253920, 426739, 426818],
#  16555: [175954],
#  16556: [175954, 253920],
#  18902: [175977],
#  119258: [175977],
#  85921: [175977],
#  272499: [175977],
#  271668: [175978],
#  271896: [175978],
#  18482: [175992],
#  272511: [175992, 639773],
#  48859: [176000],
#  225914: [176000],
#  272524: [176000],
#  16405: [176000, 869105],
#  48620: [176000],
#  48698: [176000, 427324],
#  272525: [176001],
#  272526: [176001],
#  272527: [176001],
#  17370: [176001],
#  272528: [176001],
#  272529: [176001],
#  272530: [176001],
#  272531: [176001],
#  35691: [176003, 730779],
#  272533: [176003],
#  64882: [176003],
#  30546: [176003],
#  18900: [176003],
#  16639: [176013],
#  264671: [176013],
#  15855: [176013, 427943],
#  17138: [176038, 176324],
#  15870: [176077, 176343, 426617, 428049],
#  260118: [176079],
#  20101: [176079, 381922, 382764, 383596, 869806],
#  17619: [176079],
#  15964: [176079, 176125],
#  272605: [176079],
#  272606: [176079],
#  272609: [176082],
#  18262: [176082, 254040, 638442, 638928, 639756],
#  16757: [176082],
#  256125: [176082, 639756],
#  16758: [176082, 342165, 425790],
#  230008: [176083],
#  16965: [176083],
#  272610: [176083],
#  226909: [176084],
#  52814: [176084],
#  272614: [176088],
#  272615: [176088],
#  272621: [176092],
#  17130: [176092],
#  18363: [176092, 253845],
#  16895: [176092, 640169],
#  85767: [176093],
#  16611: [176093, 426046, 639931],
#  8315: [176093, 730625, 732493],
#  140302: [176094],
#  272622: [176094],
#  272623: [176094],
#  18006: [176094, 176215],
#  12238: [176108],
#  259741: [176108, 176725],
#  16695: [176108, 176725],
#  16415: [176108, 176725],
#  16369: [176116, 176497],
#  17356: [176120],
#  119357: [176124],
#  16005: [176124],
#  119317: [176124],
#  7792: [176124],
#  16500: [176124, 868257],
#  118436: [176124, 425932],
#  16411: [176124],
#  16502: [176124],
#  97255: [176125],
#  272648: [176129],
#  272649: [176129],
#  18528: [176129],
#  272650: [176129],
#  272651: [176129],
#  223851: [176129],
#  97852: [176129],
#  130969: [176129],
#  18553: [176134],
#  16257: [176161],
#  17232: [176161],
#  16256: [176161],
#  162112: [176166],
#  272711: [176166],
#  17934: [176166, 383047],
#  15847: [176166, 383047],
#  16062: [176166, 383047, 425117, 426735],
#  272712: [176166],
#  272713: [176166],
#  8393: [176166, 426649, 427310, 638405, 638711, 639910, 868199, 870273],
#  51755: [176166],
#  272723: [176178],
#  17657: [176178],
#  16864: [176186],
#  272187: [176186],
#  272019: [176186],
#  272735: [176186, 176608],
#  7809: [176186],
#  16358: [176186, 176433],
#  7289: [176186],
#  16563: [176186, 425375],
#  59413: [176196],
#  115211: [176196, 732068],
#  99555: [176196, 732068],
#  118186: [176199],
#  272738: [176199],
#  16343: [176199, 176655, 426068],
#  272760: [176215],
#  272761: [176215],
#  16265: [176229],
#  272772: [176229],
#  18758: [176254, 639396],
#  255912: [176254, 639396],
#  17630: [176254, 382979, 383237, 425589, 427879],
#  272734: [176309],
#  205795: [176309],
#  19433: [176309],
#  272172: [176312],
#  16211: [176312, 659850],
#  272869: [176312],
#  272870: [176312],
#  272170: [176312],
#  16110: [176315],
#  272872: [176315],
#  16117: [176315],
#  16115: [176315, 870257],
#  17136: [176324],
#  271787: [176324],
#  272875: [176324],
#  118950: [176324],
#  269814: [176336],
#  15997: [176336],
#  272890: [176336],
#  16058: [176336],
#  16670: [176336],
#  15831: [176341],
#  233082: [176341],
#  272901: [176341],
#  272902: [176341],
#  113549: [176341],
#  72748: [176341],
#  24903: [176341],
#  272903: [176343],
#  15875: [176343, 638424, 869855],
#  16148: [176343, 176566, 428049],
#  17795: [176355],
#  17752: [176355],
#  141307: [176355],
#  15957: [176355],
#  18145: [176372],
#  272925: [176381],
#  272108: [176381],
#  272945: [176392],
#  272946: [176392],
#  272947: [176392],
#  272973: [176432],
#  15861: [176432],
#  272974: [176432],
#  16466: [176432],
#  15862: [176432],
#  240211: [176433, 176643],
#  19283: [176442],
#  17373: [176442, 253722],
#  272989: [176454],
#  18615: [176454],
#  16242: [176454],
#  18618: [176454],
#  272562: [176463],
#  272565: [176463],
#  16513: [176463],
#  272993: [176463],
#  272994: [176463],
#  272566: [176463],
#  16520: [176463],
#  272559: [176463],
#  15994: [176483],
#  273005: [176496],
#  273006: [176496],
#  273007: [176496],
#  34431: [176496],
#  273008: [176496],
#  273009: [176496],
#  273010: [176496],
#  273011: [176496],
#  273012: [176496],
#  273013: [176496],
#  9520: [176496],
#  18710: [176496],
#  19458: [176497],
#  271732: [176497],
#  272827: [176510],
#  272134: [176510],
#  16040: [176510],
#  16037: [176510],
#  16039: [176510],
#  119318: [176510],
#  7928: [176519],
#  15898: [176528],
#  16892: [176538],
#  5622: [176538],
#  5623: [176538],
#  18130: [176538],
#  18039: [176566],
#  272600: [176566],
#  88345: [176595],
#  18685: [176595],
#  273108: [176595],
#  88058: [176595],
#  273111: [176602],
#  17813: [176608],
#  17856: [176608],
#  18114: [176613],
#  16754: [176613],
#  16855: [176613, 871077],
#  273115: [176614],
#  19267: [176614],
#  19268: [176614],
#  19269: [176614],
#  273116: [176616],
#  47537: [176623],
#  8338: [176623, 253839, 425391, 427849, 638774, 640123],
#  273126: [176623],
#  273127: [176623],
#  273128: [176623],
#  273129: [176623],
#  273130: [176623],
#  15830: [176627],
#  18854: [176643],
#  18641: [176643],
#  273142: [176643, 253936, 639766],
#  15036: [176643, 253936],
#  273143: [176653],
#  273144: [176653],
#  273145: [176655],
#  17210: [176655],
#  17211: [176655],
#  273158: [176679],
#  217787: [176686],
#  207542: [176686],
#  63868: [176686],
#  16913: [176694],
#  273176: [176694],
#  272426: [176694],
#  18228: [176706],
#  15840: [176706],
#  18105: [176706],
#  119171: [176725],
#  272599: [176725],
#  206361: [253603, 253659, 869915],
#  240513: [253617],
#  20752: [253617, 253775, 868891],
#  3330: [253617, 253775, 868268, 868891],
#  364796: [253622],
#  158503: [253622],
#  21688: [253629],
#  114923: [253629, 869634],
#  114661: [253629, 869634],
#  8861: [253630, 427030, 427198, 658767, 731038, 869114],
#  8862: [253630, 869114],
#  8860: [253630, 731352, 731963, 732396, 733075],
#  8864: [253630, 253637, 658338],
#  364806: [253637, 658454],
#  94086: [253637, 254250],
#  364807: [253637, 253785, 253989, 254250, 869114, 869834],
#  8557: [253637,
#   253785,
#   253937,
#   254160,
#   426994,
#   427198,
#   638476,
#   658454,
#   659590,
#   869114,
#   869410,
#   870818,
#   870894],
#  266235: [253637, 427275],
#  364808: [253637,
#   253785,
#   253937,
#   254160,
#   254250,
#   869114,
#   869410,
#   869834,
#   870752,
#   870894],
#  364805: [253657],
#  265754: [253657, 342842, 427504],
#  40133: [253658, 638885],
#  272282: [253658, 253905, 342322, 638885],
#  113737: [253670, 253973],
#  364822: [253670],
#  115733: [253670, 253973, 870706],
#  9620: [253670, 426649, 658532],
#  364823: [253670],
#  364827: [253675],
#  256266: [253675],
#  175940: [253675],
#  364828: [253675],
#  9664: [253675, 254231, 730076, 730636, 731374, 979255, 980268, 980585],
#  21250: [253679, 427749, 869170],
#  364829: [253679, 342203],
#  101528: [253681],
#  101525: [253681, 427519],
#  101527: [253681, 427519],
#  16526: [253681],
#  289397: [253682, 870628],
#  19996: [253682, 869009, 870628],
#  148163: [253694],
#  308812: [253694],
#  364844: [253694],
#  160414: [253694],
#  9440: [253694, 638325],
#  364847: [253696, 426777, 428236],
#  364848: [253696],
#  270583: [253696],
#  364849: [253696],
#  364850: [253697],
#  364851: [253697, 869227],
#  175759: [253697],
#  115207: [253697, 253840, 658725, 659518, 659641, 869227],
#  18897: [253699, 253723, 253891, 254125, 254168, 425391, 639279, 870107],
#  272747: [253699, 870087],
305, 18825, 21377, 272092, 272093, 237492, 29758, 272094, 16528, 15952, 16529, 9751, 16051, 16052, 16780, 15905, 15904, 8650, 271868, 81615, 16469, 31926, 85885, 18132, 15814, 18133, 34560, 272146, 17361, 12165, 16270, 272147, 272148, 272149, 272150, 272151, 10674, 16048, 15813, 272156, 18397, 21807, 16099, 16996, 16031, 16404, 272166, 18428, 272192, 18430, 16457, 17572, 18431, 85455, 272197, 272052, 271720, 272118, 272234, 17789, 271704, 9317, 21097, 17036, 15987, 9763, 271706, 17521, 17522, 17523, 17524, 272238, 272242, 272243, 218972, 218970, 217845, 18427, 17372, 272247, 16842, 272253, 272254, 18208, 272255, 17244, 272256, 16487, 15839, 15841, 16049, 16045, 16050, 18826, 260828, 16798, 272302, 272303, 97887, 18167, 272224, 17011, 16301, 16330, 17326, 271895, 272127, 17604, 113958, 16356, 272316, 272317, 272318, 32665, 272352, 17097, 272367, 128303, 272368, 272396, 7927, 272399, 272400, 272401, 87752, 158398, 272402, 15975, 272403, 16277, 272162, 272440, 48526, 255725, 272445, 17443, 15948, 19369, 16782, 223877, 16338, 16553, 16554, 16555, 16556, 18902, 119258, 85921, 272499, 271668, 271896, 18482, 272511, 48859, 225914, 272524, 16405, 48620, 48698, 272525, 272526, 272527, 17370, 272528, 272529, 272530, 272531, 35691, 272533, 64882, 30546, 18900, 16639, 264671, 15855, 17138, 15870, 260118, 20101, 17619, 15964, 272605, 272606, 272609, 18262, 16757, 256125, 16758, 230008, 16965, 272610, 226909, 52814, 272614, 272615, 272621, 17130, 18363, 1 ...

# %%
# To get authors for a given publication:
#for i in range(len(data)):
#    if data[i]['id_publication_int'] == 342780:
#        print(data[i])

# %% [markdown]
# Definition of the function for the Jaccard distance to use as weight for the edges for the graph:

# %%
# Function to find the Jaccardian distance
def DistJaccard(lst1, lst2):
    lst1 = set(lst1)
    lst2 = set(lst2)
    return (1-float(len(lst1.intersection(lst2))) / len(lst1.union(lst2)))

# %% [markdown]
# For checking the execution time:

# %%
start_time = datetime.now()

# %% [markdown]
# Creation of the graph G with the 'author_id':

# %%
G = nx.Graph()
for author_id in authorsDict.keys():
    G.add_node(author_id)

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 7771
# Number of edges: 0
# Average degree:   0.0000

# %%
pos = nx.random_layout(G)
degrees = nx.degree(G)
nx.draw_networkx_nodes(G, pos, node_shape = "o", node_size = 0.5 , node_color = "yellow")
nx.draw_networkx_edges(G, pos, width = 0.2 , edge_color = "black", alpha = 0.5)
plt.axis('off')
plt.show()

# %%
# Loading all the publications ID's into a list for easy access
pubIdList = []
for i in range(len(data)):
    pubIdList.append(data[i]['id_publication_int'])
# 1. Create a list with all the authors' IDs for the authors wich enjoyed a conference
# 2. with intertools.combinations create all the possible pairs for each element in the list 
#    es: combinations('ABCD', 2) | AB AC AD CD
# 3. add an edge between the pairs created
for i in range(len(data)):
    authorList = []
    for j in range(len(data[i]['authors'])):
            authorList.append(data[i]['authors'][j]['author_id'])
    #for pubid in pubIdList:
     #   print(authorList)
    combinationsAll = list(itertools.combinations(authorList, 2))
    #print(combinationsAll)
    for k in combinationsAll :
        G.add_edge((k[0]), (k[1]), weight = 1 - DistJaccard(authorsDict[k[0]],authorsDict[k[1]] ))

# %%
print(combinationsAll)
# Out:
# [(205236, 143709), (205236, 205388), (205236, 143752), (143709, 205388), (143709, 143752), (205388, 143752)]

# %%
print(nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 7771
# Number of edges: 16489
# Average degree:   4.2437

# %%
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time)) # for checking the speed
pos = nx.random_layout(G)
degrees = dict(nx.degree(G))
nx.draw_networkx_nodes(G, pos, node_shape = "o", node_size =[v*0.075 for v in degrees.values()], node_color = "yellow")
nx.draw_networkx_edges(G, pos, width = 0.2 , edge_color = "black", alpha = 0.5)
plt.axis('off')
plt.show()
# Out:
# Duration: 0:00:09.802327

# %% [markdown]
# # 2. Some statistics and visualizations:

# %% [markdown]
# Create a list of IDs for the authors that have partecipated to a conference (in input):

# %%
authorsList=[]
conferenceInput = int(input("Enter the conference: "))
for i in range(len(data)):
    if data[i]['id_conference_int'] == conferenceInput :
        for j in range(len(data[i]['authors'])):
            data[i]['authors'][j]['author_id']
            authorsList.append(data[i]['authors'][j]['author_id'])
# Out:
# Enter the conference: 3052

# %%
authorsList
# Out:
# [255206,
#  255207,
#  16585,
#  255208,
#  255280,
#  255281,
#  3326,
#  20405,
#  20407,
#  255339,
#  205380,
#  115228,
#  210891,
#  255394,
#  255395,
#  255405,
#  9308,
#  175195,
#  17178,
#  176994,
#  73799,
#  24151,
#  255487,
#  255488,
#  3476,
#  255489,
#  166813,
#  13781,
#  9741,
#  8757,
#  255537,
#  21462,
#  255578,
#  113776,
#  255247,
#  82068,
#  255673,
#  255688,
#  255689,
#  255690,
#  255691,
#  113346,
#  15924,
#  255814,
#  200773,
#  93126,
#  23845,
#  208589,
#  127810,
#  255902,
#  255926,
#  9503,
#  9505,
#  9068,
#  9046,
#  9069,
#  9070,
#  255950,
#  255996,
#  20199,
#  124828,
#  239007,
#  189237,
#  255823,
#  256123,
#  256124,
#  8985,
#  8987,
#  8988,
#  19285,
#  19460,
#  8612,
#  255494,
#  256146,
#  256147,
#  9771,
#  256148,
#  20336,
#  256176,
#  256177,
#  255328,
#  256188,
#  256159,
#  256133,
#  256264,
#  256265,
#  256124,
#  256276,
#  25696,
#  255805,
#  72882,
#  72883,
#  71582,
#  71969,
#  9772,
#  114626,
#  114625,
#  114483,
#  202882,
#  256135,
#  252278,
#  83637,
#  83639,
#  255300,
#  21056,
#  70758,
#  256482,
#  256500,
#  255902,
#  20392,
#  8857,
#  256366,
#  255759,
#  255760,
#  8874,
#  19794,
#  9451,
#  8350,
#  8352,
#  151570,
#  43462,
#  9388]

# %% [markdown]
# (a): Given the conference in input, return the subgraph induced by the set of authors who have published at the input conference at least once.

# %%
confG = G.subgraph(authorsList)
map(int, authorsList)
plt.plot(authorsList, color = "red")
print('Authors IDs by ax')
plt.ylabel('Authors in conference given in input:')
plt.show()
print(nx.info(confG))
degDict = dict(nx.degree(confG))
keyList = []
degList = []
for keys in degDict.keys():
    keyList.append(keys)
    degList.append(degDict[keys])
#plt.plot(degList, keyList)
plt.hist(degList, color= "orange") #histogram for the distribution of graph degrees in the subgraph
plt.ylabel('Subgraph degree')
plt.show()
print('Subgraph induced:')
pos = nx.random_layout(confG)
nx.draw_networkx_nodes(confG, pos, node_shape = "o", node_size = [v*27 for v in degDict.values()] , node_color = "yellow")
nx.draw_networkx_edges(confG, pos, width = 0.2 , edge_color = "black", alpha = 0.5)
plt.axis('off')
plt.show()
# Out:
# Authors IDs by ax
# Name:
# Type: SubGraph
# Number of nodes: 120
# Number of edges: 117
# Average degree:   1.9500
# Subgraph induced:

# %% [markdown]
# # Now we have the graph. Computation of some centralities measures and plot them.

# %% [markdown]
# # Closeness centrality:
# Represents the mean distance between a given node and all the others.

# %%
closenessDict = nx.closeness_centrality(confG)
keyList = []
closenessList = []
for keys in closenessDict.keys():
    keyList.append(keys)
    closenessList.append(closenessDict[keys])
x = keyList
y = closenessList
print('Closeness Centrlality histogram:')
plt.ylabel('Frequency for each CC value')
plt.hist(y)
plt.show()
# Out:
# Closeness Centrlality histogram:

# %%
closenessDict
# Out:
# {3326: 0.01680672268907563,
#  3476: 0.025210084033613446,
#  8350: 0.01680672268907563,
#  8352: 0.01680672268907563,
#  8612: 0.01680672268907563,
#  8757: 0.008403361344537815,
#  8857: 0.008403361344537815,
#  8874: 0.025210084033613446,
#  8985: 0.01680672268907563,
#  8987: 0.01680672268907563,
#  8988: 0.01680672268907563,
#  9046: 0.025210084033613446,
#  9068: 0.025210084033613446,
#  9069: 0.025210084033613446,
#  9070: 0.025210084033613446,
#  9308: 0.025210084033613446,
#  9388: 0.01680672268907563,
#  9451: 0.01680672268907563,
#  9503: 0.035854341736694675,
#  9505: 0.02987861811391223,
#  9741: 0.008403361344537815,
#  9771: 0.025210084033613446,
#  9772: 0.01680672268907563,
#  13781: 0.008403361344537815,
#  15924: 0.015126050420168067,
#  16585: 0.025210084033613446,
#  17178: 0.025210084033613446,
#  19285: 0.01680672268907563,
#  19460: 0.01680672268907563,
#  19794: 0.025210084033613446,
#  20199: 0.008403361344537815,
#  20336: 0.0,
#  20392: 0.008403361344537815,
#  20405: 0.008403361344537815,
#  20407: 0.008403361344537815,
#  21056: 0.02240896358543417,
#  21462: 0.008403361344537815,
#  23845: 0.02240896358543417,
#  24151: 0.01680672268907563,
#  25696: 0.008403361344537815,
#  43462: 0.01680672268907563,
#  70758: 0.02240896358543417,
#  71582: 0.025210084033613446,
#  71969: 0.025210084033613446,
#  72882: 0.025210084033613446,
#  72883: 0.025210084033613446,
#  73799: 0.01680672268907563,
#  82068: 0.025210084033613446,
#  83637: 0.008403361344537815,
#  83639: 0.008403361344537815,
#  93126: 0.02987861811391223,
#  113346: 0.0,
#  113776: 0.025210084033613446,
#  114483: 0.01680672268907563,
#  114625: 0.01680672268907563,
#  114626: 0.01680672268907563,
#  115228: 0.01680672268907563,
#  124828: 0.01680672268907563,
#  127810: 0.011204481792717085,
#  151570: 0.01680672268907563,
#  166813: 0.008403361344537815,
#  175195: 0.025210084033613446,
#  176994: 0.01680672268907563,
#  189237: 0.01680672268907563,
#  200773: 0.008403361344537815,
#  202882: 0.01680672268907563,
#  205380: 0.01680672268907563,
#  208589: 0.02240896358543417,
#  210891: 0.01680672268907563,
#  239007: 0.01680672268907563,
#  252278: 0.0,
#  255206: 0.025210084033613446,
#  255207: 0.025210084033613446,
#  255208: 0.025210084033613446,
#  255247: 0.025210084033613446,
#  255280: 0.01680672268907563,
#  255281: 0.01680672268907563,
#  255300: 0.02987861811391223,
#  255328: 0.025210084033613446,
#  255339: 0.01680672268907563,
#  255394: 0.01680672268907563,
#  255395: 0.01680672268907563,
#  255405: 0.025210084033613446,
#  255487: 0.025210084033613446,
#  255488: 0.025210084033613446,
#  255489: 0.025210084033613446,
#  255494: 0.0,
#  255537: 0.008403361344537815,
#  255578: 0.0,
#  255673: 0.025210084033613446,
#  255688: 0.025210084033613446,
#  255689: 0.025210084033613446,
#  255690: 0.025210084033613446,
#  255691: 0.025210084033613446,
#  255759: 0.025210084033613446,
#  255760: 0.025210084033613446,
#  255805: 0.008403361344537815,
#  255814: 0.008403361344537815,
#  255823: 0.0,
#  255902: 0.01680672268907563,
#  255926: 0.035854341736694675,
#  255950: 0.0,
#  255996: 0.008403361344537815,
#  256123: 0.011204481792717085,
#  256124: 0.01680672268907563,
#  256133: 0.008403361344537815,
#  256135: 0.01680672268907563,
#  256146: 0.025210084033613446,
#  256147: 0.025210084033613446,
#  256148: 0.025210084033613446,
#  256159: 0.008403361344537815,
#  256176: 0.018907563025210086,
#  256177: 0.018907563025210086,
#  256188: 0.0,
#  256264: 0.008403361344537815,
#  256265: 0.008403361344537815,
#  256276: 0.011204481792717085,
#  256366: 0.0,
#  256482: 0.0,
#  256500: 0.011204481792717085}

# %% [markdown]
# # Betweeness centrality:
# It is a measure of centrality based on the shortest paaths.
# Fore every pair of vertices in a conncted graph, there exists at least one shortest path between the vertices such that the sum of the weights of the edegs, for a weighted graph is minimized. The betweenness centrality for each vertex is the number of these shortest paths that pass through the vertex.

# %%
betweennessDict = nx.betweenness_centrality(confG)
keyList = []
betweennessList = []
for keys in betweennessDict.keys():
    keyList.append(int(keys))
    betweennessList.append(betweennessDict[keys])
print(' Betweeness Centrality histogram:')
plt.hist(betweennessList)
plt.ylabel('Frequency for each BC value')
plt.show()
# Out:
#  Betweeness Centrality histogram:

# %%
betweennessDict
# Out:
# {3326: 0.0,
#  3476: 0.0,
#  8350: 0.0,
#  8352: 0.0,
#  8612: 0.0,
#  8757: 0.0,
#  8857: 0.0,
#  8874: 0.0,
#  8985: 0.0,
#  8987: 0.0,
#  8988: 0.0,
#  9046: 0.0,
#  9068: 0.0,
#  9069: 0.0,
#  9070: 0.0,
#  9308: 0.0,
#  9388: 0.0,
#  9451: 0.0,
#  9503: 0.0021364477994587666,
#  9505: 0.0,
#  9741: 0.0,
#  9771: 0.0,
#  9772: 0.0,
#  13781: 0.0,
#  15924: 0.0,
#  16585: 0.0,
#  17178: 0.0,
#  19285: 0.0,
#  19460: 0.0,
#  19794: 0.0,
#  20199: 0.0,
#  20336: 0.0,
#  20392: 0.0,
#  20405: 0.0,
#  20407: 0.0,
#  21056: 0.0,
#  21462: 0.0,
#  23845: 0.0,
#  24151: 0.0,
#  25696: 0.0,
#  43462: 0.0,
#  70758: 0.0,
#  71582: 0.0,
#  71969: 0.0,
#  72882: 0.0,
#  72883: 0.0,
#  73799: 0.0,
#  82068: 0.0,
#  83637: 0.0,
#  83639: 0.0,
#  93126: 0.001709158239567013,
#  113346: 0.0,
#  113776: 0.0,
#  114483: 0.0,
#  114625: 0.0,
#  114626: 0.0,
#  115228: 0.0,
#  124828: 0.0,
#  127810: 0.0,
#  151570: 0.0,
#  166813: 0.0,
#  175195: 0.0,
#  176994: 0.0,
#  189237: 0.0,
#  200773: 0.0,
#  202882: 0.0,
#  205380: 0.0,
#  208589: 0.0,
#  210891: 0.0,
#  239007: 0.0,
#  252278: 0.0,
#  255206: 0.0,
#  255207: 0.0,
#  255208: 0.0,
#  255247: 0.0,
#  255280: 0.0,
#  255281: 0.0,
#  255300: 0.001709158239567013,
#  255328: 0.0002848597065945022,
#  255339: 0.0,
#  255394: 0.0,
#  255395: 0.0,
#  255405: 0.0,
#  255487: 0.0,
#  255488: 0.0,
#  255489: 0.0,
#  255494: 0.0,
#  255537: 0.0,
#  255578: 0.0,
#  255673: 0.0,
#  255688: 0.0,
#  255689: 0.0,
#  255690: 0.0,
#  255691: 0.0,
#  255759: 0.0,
#  255760: 0.0,
#  255805: 0.0,
#  255814: 0.0,
#  255823: 0.0,
#  255902: 0.0001424298532972511,
#  255926: 0.0021364477994587666,
#  255950: 0.0,
#  255996: 0.0,
#  256123: 0.0,
#  256124: 0.0001424298532972511,
#  256133: 0.0,
#  256135: 0.0,
#  256146: 0.0,
#  256147: 0.0,
#  256148: 0.0,
#  256159: 0.0,
#  256176: 0.0,
#  256177: 0.0,
#  256188: 0.0,
#  256264: 0.0,
#  256265: 0.0,
#  256276: 0.0,
#  256366: 0.0,
#  256482: 0.0,
#  256500: 0.0}

# %%
degreeDict = nx.degree_centrality(confG)
keyList = []
degreeList = []
for keys in degreeDict.keys():
    keyList.append(int(keys))
    degreeList.append(degreeDict[keys])
print(' Degree Centrality histogram:')
plt.hist(degreeList)
plt.ylabel('Frequency for each D value')
plt.show()
# Out:
#  Degree Centrality histogram:

# %%
degreeDict
# Out:
# {3326: 0.01680672268907563,
#  3476: 0.025210084033613446,
#  8350: 0.01680672268907563,
#  8352: 0.01680672268907563,
#  8612: 0.01680672268907563,
#  8757: 0.008403361344537815,
#  8857: 0.008403361344537815,
#  8874: 0.025210084033613446,
#  8985: 0.01680672268907563,
#  8987: 0.01680672268907563,
#  8988: 0.01680672268907563,
#  9046: 0.025210084033613446,
#  9068: 0.025210084033613446,
#  9069: 0.025210084033613446,
#  9070: 0.025210084033613446,
#  9308: 0.025210084033613446,
#  9388: 0.01680672268907563,
#  9451: 0.01680672268907563,
#  9503: 0.025210084033613446,
#  256500: 0.008403361344537815}

# %% [markdown]
# (b): Given in input an author and an integer d, get the subgraph induced by the nodes that have hop distance at most equal to d with the input author. Then, visualize the graph.

# %%
author = int(input("Enter the author ID: "))
d = int(input("Enter the distance: "))
def neighbourhood(a, dist, graph):
    l = []
    l.extend(G.neighbors(a))    
    for i in range(dist - 1):
        for el in l:
            l.extend(G.neighbors(el))
            l = list(set(l))
    return l   
output = neighbourhood(author, d, G)
# Out:
# Enter the author ID: 10
# Enter the distance: 4

# %%
output
# Out:
# [71680,
#  10,
#  118802,
#  260118,
#  20506,
#  20507,
#  114729,
#  356399,
#  2095,
#  16435,
#  426037,
#  426038,
#  524355,
#  16452,
#  118856,
#  489545,
#  524360,
#  501840,
#  53334,
#  53335,
#  137306,
#  82011,
#  524383,
#  829535,
#  489581,
#  20596,
#  20598,
#  8312,
#  243843,
#  71827,
#  16536,
#  829594,
#  489630,
#  16542,
#  489631,
#  16558,
#  829625,
#  71867,
#  16583,
#  8393,
#  16589,
#  272605,
#  272606,
#  278757,
#  20711,
#  256237,
#  12527,
#  364789,
#  10494,
#  35071,
#  364806,
#  364807,
#  364808,
#  364822,
#  364823,
#  61721,
#  489764,
#  364842,
#  364843,
#  504106,
#  63791,
#  8497,
#  364856,
#  364857,
#  16703,
#  162112,
#  8513,
#  322,
#  272711,
#  272712,
#  272713,
#  16722,
#  489811,
#  489812,
#  303452,
#  364904,
#  364905,
#  8556,
#  8557,
#  364913,
#  491893,
#  256394,
#  489884,
#  256420,
#  260517,
#  256423,
#  364968,
#  119221,
#  225741,
#  8657,
#  121298,
#  8659,
#  365014,
#  365015,
#  365016,
#  489945,
#  16867,
#  365042,
#  18932,
#  115205,
#  8724,
#  18965,
#  285215,
#  51755,
#  16940,
#  8750,
#  113210,
#  113212,
#  94793,
#  365139,
#  16979,
#  447062,
#  447063,
#  447064,
#  16998,
#  289387,
#  365163,
#  365167,
#  31344,
#  19062,
#  273040,
#  365200,
#  365201,
#  490138,
#  8861,
#  8862,
#  8863,
#  8864,
#  17055,
#  25252,
#  19111,
#  490153,
#  490154,
#  490155,
#  490156,
#  19113,
#  430793,
#  682697,
#  289481,
#  113373,
#  21215,
#  19193,
#  19194,
#  19195,
#  197372,
#  197387,
#  113423,
#  113425,
#  8985,
#  490267,
#  8988,
#  8987,
#  346920,
#  9001,
#  11050,
#  9003,
#  17199,
#  285488,
#  21309,
#  197440,
#  21324,
#  451405,
#  265044,
#  103263,
#  695155,
#  486264,
#  344954,
#  261006,
#  88996,
#  490435,
#  490436,
#  490437,
#  199626,
#  58319,
#  17360,
#  519122,
#  15329,
#  15330,
#  97255,
#  17386,
#  21485,
#  1011,
#  93174,
#  113665,
#  310276,
#  33797,
#  115733,
#  150553,
#  17435,
#  17436,
#  17437,
#  289822,
#  15402,
#  113737,
#  216148,
#  1117,
#  9321,
#  9323,
#  9324,
#  72814,
#  695408,
#  255103,
#  3199,
#  382087,
#  52368,
#  13470,
#  42146,
#  115874,
#  179389,
#  17619,
#  17629,
#  9438,
#  9440,
#  56553,
#  89323,
#  25840,
#  111859,
#  17655,
#  9472,
#  271623,
#  290064,
#  17685,
#  17686,
#  77080,
#  17689,
#  881959,
#  320810,
#  34100,
#  161082,
#  17729,
#  7494,
#  255327,
#  200033,
#  372069,
#  460136,
#  216432,
#  118131,
#  9601,
#  9602,
#  23942,
#  9620,
#  9621,
#  17824,
#  118177,
#  118178,
#  265637,
#  556464,
#  17841,
#  556465,
#  161203,
#  81341,
#  15806,
#  15805,
#  9664,
#  15847,
#  419303,
#  34292,
#  1529,
#  15866,
#  11771,
#  15874,
#  15875,
#  882180,
#  359942,
#  108039,
#  17934,
#  22032,
#  93714,
#  17944,
#  11808,
#  36385,
#  290338,
#  300578,
#  79409,
#  130611,
#  15924,
#  161333,
#  15925,
#  503350,
#  419386,
#  20030,
#  15938,
#  118347,
#  15950,
#  32335,
#  9810,
#  15964,
#  34402,
#  61034,
#  61037,
#  386670,
#  167536,
#  20101,
#  20114,
#  20115,
#  16062,
#  272070,
#  272071,
#  523977,
#  489170,
#  489171,
#  272083,
#  489175,
#  204515,
#  272100,
#  255720,
#  524015,
#  524016,
#  210671,
#  202497,
#  40706,
#  255748,
#  419591,
#  18188,
#  118546,
#  44819,
#  292661,
#  77635,
#  139081,
#  255818,
#  36690,
#  22359,
#  290656,
#  309092,
#  309094,
#  272230,
#  16238,
#  141180,
#  94086,
#  69517,
#  18318,
#  16278,
#  16294,
#  20391,
#  518061,
#  518062,
#  38842,
#  16315,
#  196540,
#  85964,
#  18382,
#  18383,
#  489430,
#  489431,
#  16361,
#  489451,
#  253931,
#  6126,
#  266235,
#  161790]

# %%
G1 = G.subgraph(output)
print(nx.info(G1))
# Out:
# Name:
# Type: Graph
# Number of nodes: 350
# Number of edges: 1120
# Average degree:   6.4000

# %%
pos = nx.random_layout(G1)
nx.draw_networkx_nodes(G1, pos, node_shape = "o", node_size = [v*6 for v in degrees.values()] , node_color = "yellow")
nx.draw_networkx_edges(G1, pos, width = 0.2 , edge_color = "black", alpha = 0.5)
plt.axis('off')
plt.show()

# %% [markdown]
# # 3. Compute some generalized version of the Erdos number

# %% [markdown]
# (a): Verify the presence of a path between Aris and the input author:

# %%
authorID = int(input("Enter the ID of the author you want to compute the distance from Aris: "))
nx.has_path(G, source = authorID, target = 256176)
# Out:
# Enter the ID of the author you want to compute the distance from Aris: 10
# True

# %%
def Dijkstra(graph, source, target):    
    dist = {}
    prev = {}
    visited = set()
    for v in graph:
        dist[v] = float('inf')
        prev[v] = None
    dist[source] = 0

    while sum(1 for k, v in dist.items() if k not in visited and v < float('inf')):
        sorted_x = [v for v in sorted(dist, key=dist.get) if v not in visited]
        u = sorted_x[0]
        if u in visited:
            continue
        visited.add(u)
        if u == target:
            break

        for v in graph.neighbors(u):
            alt = dist[u] + graph[u][v]['weight']
            if alt < dist[v]:
                dist[v] = alt
                prev[v] = u
            
    return dist[target]

# %%
Dijkstra(G, authorID, 256176)
# Out:
# 0.6428403897444145

# %% [markdown]
# (b): Take in input a subset of nodes (cardinality smaller than 21) and returns, for each node of the graph, its GroupNumber, defined as the minimum SP between u and v, where v is a node in the graph and u belongs to I, which is the set of input nodes.

# %%
subset = list(map(int, input('Insert a subset (of cardinality smaller than 21) of nodes: ').split(" ")))
for j in subset:
    for i in G.nodes():    
        if nx.has_path(G, i, j):
            print("The Group Number for ", i, "with", j, "is: ", Dijkstra(G, i, j))
# Out:
# Insert a subset (of cardinality smaller than 21) of nodes: 10
# The Group Number for  20405 with 10 is:  1.12027355599337
# The Group Number for  20407 with 10 is:  1.12027355599337
# The Group Number for  255405 with 10 is:  1.8954609116373815
# The Group Number for  9308 with 10 is:  1.645460911637382
# The Group Number for  175195 with 10 is:  1.978794244970715
# The Group Number for  17178 with 10 is:  1.978794244970715
# The Group Number for  255537 with 10 is:  0.9606893106893106
# The Group Number for  21462 with 10 is:  0.4606893106893106
# The Group Number for  255688 with 10 is:  0.5956099456099456
# The Group Number for  255689 with 10 is:  0.9289432789432789
# The Group Number for  255690 with 10 is:  0.9289432789432789
# The Group Number for  255691 with 10 is:  0.9289432789432789
# The Group Number for  15924 with 10 is:  0.4285546754587002
# The Group Number for  8985 with 10 is:  0.4608437314319668
# The Group Number for  8987 with 10 is:  0.39893896952720487
# The Group Number for  8988 with 10 is:  0.32751039809863347
# The Group Number for  19285 with 10 is:  0.49680864371266853
# The Group Number for  19460 with 10 is:  0.6968086437126685
# The Group Number for  8612 with 10 is:  0.8301419770460018
# The Group Number for  256176 with 10 is:  0.6428403897444145
# The Group Number for  256177 with 10 is:  0.6954719686917828
# The Group Number for  255328 with 10 is:  0.5952213421253668
# The Group Number for  114483 with 10 is:  1.809040959040959
# The Group Number for  202882 with 10 is:  2.142374292374292
# The Group Number for  256135 with 10 is:  2.009040959040959
# The Group Number for  256482 with 10 is:  0.440241131417602
# The Group Number for  20392 with 10 is:  0.6594988344988345
# The Group Number for  8857 with 10 is:  0.8261655011655011
# The Group Number for  8819 with 10 is:  0.9392607392607392
# The Group Number for  271611 with 10 is:  0.9392607392607392
# The Group Number for  16249 with 10 is:  0.9392607392607392
# The Group Number for  19355 with 10 is:  0.9392607392607392
# The Group Number for  16145 with 10 is:  0.6892607392607392
# The Group Number for  18433 with 10 is:  0.9392607392607392
# The Group Number for  223848 with 10 is:  0.9392607392607392
# The Group Number for  271612 with 10 is:  0.9392607392607392
# The Group Number for  175489 with 10 is:  0.9392607392607392
# The Group Number for  271613 with 10 is:  0.9392607392607392
# The Group Number for  17368 with 10 is:  0.9392607392607392
# The Group Number for  271614 with 10 is:  0.9392607392607392
# The Group Number for  17611 with 10 is:  0.8559274059274058
# The Group Number for  16521 with 10 is:  0.9392607392607392
# The Group Number for  168357 with 10 is:  0.8892607392607391
# The Group Number for  271615 with 10 is:  0.9392607392607392
# The Group Number for  271616 with 10 is:  0.9392607392607392
# The Group Number for  17509 with 10 is:  0.8956099456099457
# The Group Number for  17973 with 10 is:  0.8956099456099457
# The Group Number for  17974 with 10 is:  0.7804695304695303
# The Group Number for  16665 with 10 is:  0.8622766122766123
# The Group Number for  16837 with 10 is:  0.6956099456099457
# The Group Number for  16867 with 10 is:  0.47225768297749726
# The Group Number for  271623 with 10 is:  0.48416244488225924
# The Group Number for  17824 with 10 is:  0.5546752653950797
# The Group Number for  15938 with 10 is:  0.40082911154892586
# The Group Number for  17423 with 10 is:  0.9487234987234986
# The Group Number for  15815 with 10 is:  0.7487234987234986
# The Group Number for  17426 with 10 is:  0.9153901653901653
# The Group Number for  16053 with 10 is:  1.0403901653901653
# The Group Number for  15816 with 10 is:  1.054279054279054
# The Group Number for  16309 with 10 is:  0.7262259369457512
# The Group Number for  15983 with 10 is:  1.0119402226600371
# The Group Number for  15982 with 10 is:  0.5833687940886084
# The Group Number for  17853 with 10 is:  0.8376123876123874
# The Group Number for  16752 with 10 is:  0.8042790542790541
# The Group Number for  17184 with 10 is:  0.6376123876123875
# The Group Number for  17829 with 10 is:  0.7817814925013067
# The Group Number for  15850 with 10 is:  0.61511482583464
# The Group Number for  16486 with 10 is:  1.0079719686917827
# The Group Number for  18268 with 10 is:  0.81511482583464
# The Group Number for  101615 with 10 is:  1.1284936253976499
# The Group Number for  15939 with 10 is:  0.9951602920643168
# The Group Number for  17770 with 10 is:  0.7951602920643168
# The Group Number for  15871 with 10 is:  1.4304695304695305
# The Group Number for  15872 with 10 is:  0.9804695304695302
# The Group Number for  18686 with 10 is:  1.18046953046953
# The Group Number for  271767 with 10 is:  1.3754079254079254
# The Group Number for  16222 with 10 is:  1.042074592074592
# The Group Number for  264678 with 10 is:  1.3754079254079254
# The Group Number for  17002 with 10 is:  1.3754079254079254
# The Group Number for  15858 with 10 is:  1.0941770647653
# The Group Number for  16438 with 10 is:  1.0941770647653
# The Group Number for  16884 with 10 is:  1.3754079254079254
# The Group Number for  16830 with 10 is:  1.1775103980986334
# The Group Number for  271768 with 10 is:  1.3754079254079254
# The Group Number for  17206 with 10 is:  1.6737234987234988
# The Group Number for  271797 with 10 is:  1.1657863765061909
# The Group Number for  271798 with 10 is:  1.3324530431728574
# The Group Number for  271799 with 10 is:  1.1657863765061909
# The Group Number for  271800 with 10 is:  1.1657863765061909
# The Group Number for  271801 with 10 is:  1.1657863765061909
# The Group Number for  271802 with 10 is:  1.1657863765061909
# The Group Number for  21484 with 10 is:  0.9991197098395241
# The Group Number for  16390 with 10 is:  1.9356893106893107
# The Group Number for  271839 with 10 is:  1.9356893106893107
# The Group Number for  16392 with 10 is:  1.4356893106893107
# The Group Number for  21665 with 10 is:  0.8489389695272048
# The Group Number for  17292 with 10 is:  0.8489389695272048
# The Group Number for  15866 with 10 is:  0.5989389695272048
# The Group Number for  15884 with 10 is:  1.2971966329164468
# The Group Number for  15883 with 10 is:  1.2971966329164468
# The Group Number for  15986 with 10 is:  0.9638632995831139
# The Group Number for  15885 with 10 is:  1.2971966329164468
# The Group Number for  109393 with 10 is:  1.4737234987234986
# The Group Number for  271875 with 10 is:  1.9237234987234988
# The Group Number for  271882 with 10 is:  1.1138028638028636
# The Group Number for  17654 with 10 is:  1.1138028638028636
# The Group Number for  58971 with 10 is:  1.1138028638028636
# The Group Number for  271883 with 10 is:  1.1138028638028636
# The Group Number for  16538 with 10 is:  0.8737234987234986
# The Group Number for  17345 with 10 is:  1.1237234987234985
# The Group Number for  16201 with 10 is:  1.1237234987234985
# The Group Number for  16042 with 10 is:  1.2403901653901652
# The Group Number for  18679 with 10 is:  0.8603529210727353
# The Group Number for  16244 with 10 is:  0.8424957782155925
# The Group Number for  16674 with 10 is:  0.7174957782155925
# The Group Number for  16080 with 10 is:  1.445609945609946
# The Group Number for  11434 with 10 is:  1.778943278943279
# The Group Number for  16020 with 10 is:  1.1122766122766121
# The Group Number for  271930 with 10 is:  1.6059274059274058
# The Group Number for  18254 with 10 is:  1.6059274059274058
# The Group Number for  18276 with 10 is:  1.5225940725940723
# The Group Number for  271931 with 10 is:  1.2725940725940728
# The Group Number for  85454 with 10 is:  1.6059274059274058
# The Group Number for  16231 with 10 is:  1.6059274059274058
# The Group Number for  16232 with 10 is:  1.6725940725940722
# The Group Number for  271962 with 10 is:  0.9392607392607392
# The Group Number for  271963 with 10 is:  0.8344988344988346
# The Group Number for  271785 with 10 is:  0.8559274059274058
# The Group Number for  16557 with 10 is:  0.8344988344988346
# The Group Number for  271969 with 10 is:  1.1892607392607393
# The Group Number for  271970 with 10 is:  1.1892607392607393
# The Group Number for  272008 with 10 is:  0.9537008742891095
# The Group Number for  16166 with 10 is:  0.7037008742891095
# The Group Number for  111156 with 10 is:  1.2610855218053358
# The Group Number for  17862 with 10 is:  0.9277521884720027
# The Group Number for  111155 with 10 is:  1.5944188551386693
# The Group Number for  19242 with 10 is:  0.7262259369457512
# The Group Number for  17917 with 10 is:  0.7262259369457512
# The Group Number for  210526 with 10 is:  0.7262259369457512
# The Group Number for  18803 with 10 is:  0.7262259369457512
# The Group Number for  40393 with 10 is:  0.7262259369457512
# The Group Number for  20793 with 10 is:  0.8621386353584495
# The Group Number for  272067 with 10 is:  0.6954719686917828
# The Group Number for  272068 with 10 is:  0.7413170163170164
# The Group Number for  16617 with 10 is:  0.6954719686917828
# The Group Number for  272071 with 10 is:  0.4813565519447873
# The Group Number for  272083 with 10 is:  0.39893896952720487
# The Group Number for  256423 with 10 is:  0.47036754095577626
# The Group Number for  20596 with 10 is:  0.47036754095577626
# The Group Number for  17027 with 10 is:  0.8441770647653001
# The Group Number for  19305 with 10 is:  1.1775103980986334
# The Group Number for  18825 with 10 is:  1.3441770647653
# The Group Number for  21377 with 10 is:  1.6059274059274058
# The Group Number for  272092 with 10 is:  1.6059274059274058
# The Group Number for  272093 with 10 is:  1.6059274059274058
# The Group Number for  237492 with 10 is:  1.6059274059274058
# The Group Number for  29758 with 10 is:  1.6059274059274058
# The Group Number for  272094 with 10 is:  1.6059274059274058
# The Group Number for  16528 with 10 is:  0.9817204424402567
# The Group Number for  15952 with 10 is:  0.9157863765061908
# The Group Number for  16529 with 10 is:  0.9638632995831139
# The Group Number for  9751 with 10 is:  0.8388632995831139
# The Group Number for  16051 with 10 is:  0.9487234987234986
# The Group Number for  16052 with 10 is:  0.9487234987234986
# The Group Number for  16780 with 10 is:  0.6616447278211984
# The Group Number for  15905 with 10 is:  0.6457356369121074
# The Group Number for  15904 with 10 is:  0.5885927797692503
# The Group Number for  8650 with 10 is:  0.4457356369121075
# The Group Number for  271868 with 10 is:  0.9219261131025835
# The Group Number for  81615 with 10 is:  0.9219261131025835
# The Group Number for  16469 with 10 is:  0.9219261131025835
# The Group Number for  31926 with 10 is:  0.8385927797692503
# The Group Number for  272147 with 10 is:  0.9392607392607392
# The Group Number for  272148 with 10 is:  0.9392607392607392
# The Group Number for  272149 with 10 is:  0.9392607392607392
# The Group Number for  272150 with 10 is:  0.9392607392607392
# The Group Number for  272151 with 10 is:  0.9392607392607392
# The Group Number for  10674 with 10 is:  1.5237234987234989
# The Group Number for  16048 with 10 is:  1.7737234987234989
# The Group Number for  15813 with 10 is:  1.2737234987234989
# The Group Number for  21807 with 10 is:  1.9237234987234988
# The Group Number for  16099 with 10 is:  1.9237234987234988
# The Group Number for  16996 with 10 is:  1.5225940725940723
# The Group Number for  16031 with 10 is:  1.4059274059274056
# The Group Number for  16404 with 10 is:  1.0725940725940726
# The Group Number for  272166 with 10 is:  1.4059274059274056
# The Group Number for  18428 with 10 is:  1.366122766122766
# The Group Number for  272192 with 10 is:  1.366122766122766
# The Group Number for  18430 with 10 is:  1.366122766122766
# The Group Number for  16457 with 10 is:  1.0327894327894327
# The Group Number for  17572 with 10 is:  1.366122766122766
# The Group Number for  18431 with 10 is:  1.366122766122766
# The Group Number for  85455 with 10 is:  1.9225940725940727
# The Group Number for  272197 with 10 is:  1.9225940725940727
# The Group Number for  272052 with 10 is:  1.5138028638028636
# The Group Number for  271720 with 10 is:  1.2690226440226442
# The Group Number for  272118 with 10 is:  1.4356893106893107
# The Group Number for  272234 with 10 is:  1.4356893106893107
# The Group Number for  17789 with 10 is:  1.4356893106893107
# The Group Number for  271704 with 10 is:  1.4356893106893107
# The Group Number for  9317 with 10 is:  0.9356893106893106
# The Group Number for  21097 with 10 is:  1.4356893106893107
# The Group Number for  17036 with 10 is:  1.4356893106893107
# The Group Number for  15987 with 10 is:  1.1856893106893107
# The Group Number for  9763 with 10 is:  1.2690226440226442
# The Group Number for  271706 with 10 is:  0.9356893106893106
# The Group Number for  272242 with 10 is:  1.009507056411081
# The Group Number for  272243 with 10 is:  1.5095070564110808
# The Group Number for  218972 with 10 is:  1.5095070564110808
# The Group Number for  218970 with 10 is:  1.5095070564110808
# The Group Number for  217845 with 10 is:  1.1424963924963922
# The Group Number for  18427 with 10 is:  1.260843731431967
# The Group Number for  17372 with 10 is:  0.7608437314319667
# The Group Number for  272247 with 10 is:  1.260843731431967
# The Group Number for  16842 with 10 is:  1.0941770647653
# The Group Number for  16487 with 10 is:  0.81511482583464
# The Group Number for  15839 with 10 is:  0.7579719686917828
# The Group Number for  15841 with 10 is:  0.7817814925013067
# The Group Number for  16049 with 10 is:  1.707056832056832
# The Group Number for  16045 with 10 is:  1.0403901653901653
# The Group Number for  16050 with 10 is:  1.707056832056832
# The Group Number for  18826 with 10 is:  1.3737234987234985
# The Group Number for  260828 with 10 is:  0.9537008742891095
# The Group Number for  16798 with 10 is:  0.9537008742891095
# The Group Number for  272224 with 10 is:  1.6153901653901652
# The Group Number for  17011 with 10 is:  1.6153901653901652
# The Group Number for  16301 with 10 is:  1.4153901653901655
# The Group Number for  16330 with 10 is:  1.6153901653901652
# The Group Number for  32665 with 10 is:  1.5936862544060686
# The Group Number for  272352 with 10 is:  1.5936862544060686
# The Group Number for  17097 with 10 is:  1.260352921072735
# The Group Number for  272367 with 10 is:  1.366122766122766
# The Group Number for  16277 with 10 is:  1.7690226440226442
# The Group Number for  272162 with 10 is:  1.7690226440226442
# The Group Number for  272440 with 10 is:  1.7690226440226442
# The Group Number for  48526 with 10 is:  1.4356893106893107
# The Group Number for  19369 with 10 is:  1.445609945609946
# The Group Number for  16782 with 10 is:  1.445609945609946
# The Group Number for  223877 with 10 is:  1.5190226440226442
# The Group Number for  16338 with 10 is:  1.5190226440226442
# The Group Number for  16553 with 10 is:  0.7920995670995671
# The Group Number for  16554 with 10 is:  0.5420995670995671
# The Group Number for  16555 with 10 is:  0.7920995670995671
# The Group Number for  16556 with 10 is:  0.5837662337662337
# The Group Number for  271668 with 10 is:  0.9219261131025835
# The Group Number for  271896 with 10 is:  0.9219261131025835
# The Group Number for  18482 with 10 is:  1.0586435193633337
# The Group Number for  272511 with 10 is:  1.0407863765061909
# The Group Number for  48859 with 10 is:  0.9392607392607392
# The Group Number for  225914 with 10 is:  0.9392607392607392
# The Group Number for  272524 with 10 is:  0.9392607392607392
# The Group Number for  16405 with 10 is:  0.8225940725940725
# The Group Number for  48620 with 10 is:  0.9392607392607392
# The Group Number for  48698 with 10 is:  0.4892607392607392
# The Group Number for  272525 with 10 is:  1.389260739260739
# The Group Number for  272526 with 10 is:  1.389260739260739
# The Group Number for  272527 with 10 is:  1.389260739260739
# The Group Number for  17370 with 10 is:  1.389260739260739
# The Group Number for  272528 with 10 is:  1.389260739260739
# The Group Number for  272529 with 10 is:  1.389260739260739
# The Group Number for  272530 with 10 is:  1.389260739260739
# The Group Number for  272531 with 10 is:  1.389260739260739
# The Group Number for  16639 with 10 is:  1.5407863765061904
# The Group Number for  264671 with 10 is:  1.5407863765061904
# The Group Number for  15855 with 10 is:  1.0407863765061909
# The Group Number for  15870 with 10 is:  0.5608437314319668
# The Group Number for  260118 with 10 is:  0.4873376623376623
# The Group Number for  20101 with 10 is:  0.28733766233766234
# The Group Number for  17619 with 10 is:  0.4873376623376623
# The Group Number for  15964 with 10 is:  0.45400432900432897
# The Group Number for  272605 with 10 is:  0.4873376623376623
# The Group Number for  272606 with 10 is:  0.4873376623376623
# The Group Number for  272609 with 10 is:  1.1536068893267037
# The Group Number for  18262 with 10 is:  0.9536068893267037
# The Group Number for  16757 with 10 is:  1.1536068893267037
# The Group Number for  256125 with 10 is:  1.3464640321838464
# The Group Number for  16758 with 10 is:  1.0964640321838464
# The Group Number for  230008 with 10 is:  1.4153901653901655
# The Group Number for  16965 with 10 is:  1.4153901653901655
# The Group Number for  272610 with 10 is:  1.4153901653901655
# The Group Number for  272614 with 10 is:  1.6153901653901652
# The Group Number for  272615 with 10 is:  1.6153901653901652
# The Group Number for  85767 with 10 is:  0.9817204424402567
# The Group Number for  16611 with 10 is:  0.9277521884720027
# The Group Number for  8315 with 10 is:  0.7277521884720027
# The Group Number for  12238 with 10 is:  1.6059274059274058
# The Group Number for  259741 with 10 is:  1.1059274059274058
# The Group Number for  16695 with 10 is:  1.1059274059274058
# The Group Number for  16415 with 10 is:  1.1059274059274058
# The Group Number for  17356 with 10 is:  0.9817204424402567
# The Group Number for  119357 with 10 is:  1.282789432789433
# The Group Number for  16005 with 10 is:  1.282789432789433
# The Group Number for  119317 with 10 is:  1.282789432789433
# The Group Number for  7792 with 10 is:  1.282789432789433
# The Group Number for  16500 with 10 is:  0.7827894327894327
# The Group Number for  118436 with 10 is:  1.116122766122766
# The Group Number for  16411 with 10 is:  1.282789432789433
# The Group Number for  16502 with 10 is:  1.282789432789433
# The Group Number for  97255 with 10 is:  0.954004329004329
# The Group Number for  18553 with 10 is:  0.8489389695272048
# The Group Number for  162112 with 10 is:  0.3335561497326204
# The Group Number for  272711 with 10 is:  0.3335561497326204
# The Group Number for  17934 with 10 is:  0.31966726084373154
# The Group Number for  15847 with 10 is:  0.31966726084373154
# The Group Number for  16062 with 10 is:  0.2994652406417113
# The Group Number for  272712 with 10 is:  0.3335561497326204
# The Group Number for  272713 with 10 is:  0.3335561497326204
# The Group Number for  8393 with 10 is:  0.20855614973262038
# The Group Number for  51755 with 10 is:  0.3335561497326204
# The Group Number for  16265 with 10 is:  1.4275103980986334
# The Group Number for  272772 with 10 is:  1.4275103980986334
# The Group Number for  18758 with 10 is:  0.5396657865698113
# The Group Number for  255912 with 10 is:  0.5396657865698113
# The Group Number for  17630 with 10 is:  0.49744503862150935
# The Group Number for  272172 with 10 is:  2.248723498723499
# The Group Number for  16211 with 10 is:  1.748723498723499
# The Group Number for  272869 with 10 is:  2.248723498723499
# The Group Number for  272870 with 10 is:  2.248723498723499
# The Group Number for  272170 with 10 is:  2.248723498723499
# The Group Number for  272903 with 10 is:  0.7275103980986334
# The Group Number for  15875 with 10 is:  0.3941770647653001
# The Group Number for  16148 with 10 is:  0.5941770647653001
# The Group Number for  19283 with 10 is:  1.0280395043552937
# The Group Number for  17373 with 10 is:  0.5280395043552938
# The Group Number for  272989 with 10 is:  0.8055910163108305
# The Group Number for  18615 with 10 is:  0.8055910163108305
# The Group Number for  16242 with 10 is:  0.8055910163108305
# The Group Number for  18618 with 10 is:  0.8055910163108305
# The Group Number for  272562 with 10 is:  1.9237234987234988
# The Group Number for  272565 with 10 is:  1.9237234987234988
# The Group Number for  16513 with 10 is:  1.9237234987234988
# The Group Number for  272993 with 10 is:  1.9237234987234988
# The Group Number for  272994 with 10 is:  1.9237234987234988
# The Group Number for  272566 with 10 is:  1.9237234987234988
# The Group Number for  16520 with 10 is:  1.9237234987234988
# The Group Number for  272559 with 10 is:  1.9237234987234988
# The Group Number for  15994 with 10 is:  1.2610855218053358
# The Group Number for  273005 with 10 is:  1.5190226440226442
# The Group Number for  273006 with 10 is:  1.5190226440226442
# The Group Number for  273007 with 10 is:  1.5190226440226442
# The Group Number for  34431 with 10 is:  1.5190226440226442
# The Group Number for  273008 with 10 is:  1.5190226440226442
# The Group Number for  273009 with 10 is:  1.5190226440226442
# The Group Number for  273010 with 10 is:  1.5190226440226442
# The Group Number for  273011 with 10 is:  1.5190226440226442
# The Group Number for  273012 with 10 is:  1.5190226440226442
# The Group Number for  273013 with 10 is:  1.5190226440226442
# The Group Number for  9520 with 10 is:  1.5190226440226442
# The Group Number for  18710 with 10 is:  1.5190226440226442
# The Group Number for  18039 with 10 is:  0.9275103980986333
# The Group Number for  272600 with 10 is:  0.9275103980986333
# The Group Number for  273111 with 10 is:  0.9537008742891095
# The Group Number for  18114 with 10 is:  0.9487234987234986
# The Group Number for  16754 with 10 is:  0.9487234987234986
# The Group Number for  16855 with 10 is:  0.9153901653901653
# The Group Number for  47537 with 10 is:  0.6749023035787741
# The Group Number for  8338 with 10 is:  0.5082356369121075
# The Group Number for  273126 with 10 is:  0.6749023035787741
# The Group Number for  273127 with 10 is:  0.6749023035787741
# The Group Number for  273128 with 10 is:  0.6749023035787741
# The Group Number for  273129 with 10 is:  0.6749023035787741
# The Group Number for  273130 with 10 is:  0.6749023035787741
# The Group Number for  273158 with 10 is:  0.9817204424402567
# The Group Number for  18228 with 10 is:  1.0913053020251162
# The Group Number for  15840 with 10 is:  1.0913053020251162
# The Group Number for  18105 with 10 is:  1.0913053020251162
# The Group Number for  119171 with 10 is:  1.1892607392607393
# The Group Number for  272599 with 10 is:  1.1892607392607393
# The Group Number for  240513 with 10 is:  1.3889249639249637
# The Group Number for  20752 with 10 is:  1.1627344877344874
# The Group Number for  3330 with 10 is:  1.1389249639249637
# The Group Number for  364796 with 10 is:  1.0586435193633337
# The Group Number for  158503 with 10 is:  1.0586435193633337
# The Group Number for  21688 with 10 is:  1.2861795067677422
# The Group Number for  114923 with 10 is:  0.786179506767742
# The Group Number for  114661 with 10 is:  0.786179506767742
# The Group Number for  8861 with 10 is:  0.31783216783216783
# The Group Number for  8862 with 10 is:  0.3420745920745921
# The Group Number for  8860 with 10 is:  0.4178321678321678
# The Group Number for  8864 with 10 is:  0.33449883449883455
# The Group Number for  364806 with 10 is:  0.3420745920745921
# The Group Number for  94086 with 10 is:  0.45116550116550114
# The Group Number for  364807 with 10 is:  0.4087412587412588
# The Group Number for  8557 with 10 is:  0.3814176020058373
# The Group Number for  266235 with 10 is:  0.3420745920745921
# The Group Number for  364808 with 10 is:  0.2511655011655012
# The Group Number for  40133 with 10 is:  1.4841102310142555
# The Group Number for  272282 with 10 is:  0.9841102310142558
# The Group Number for  113737 with 10 is:  0.5585561497326204
# The Group Number for  364822 with 10 is:  0.6418894830659536
# The Group Number for  115733 with 10 is:  0.5085561497326203
# The Group Number for  9620 with 10 is:  0.30855614973262036
# The Group Number for  364823 with 10 is:  0.6418894830659536
# The Group Number for  364827 with 10 is:  0.5197552447552447
